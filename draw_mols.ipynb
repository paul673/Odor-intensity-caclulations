# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Draw

# %%
df = pd.read_csv("src/smiles_pine.csv")
df.head()
# Out:
#    oil_id  compound_id  composition   id                 name  \
# 0    3133            4        0.281    4         alpha-Pinene
# 1    3133           10        0.237   10       delta-3-Carene
# 2    3133          129        0.049  129  Caryophyllene oxide
# 3    3133           50        0.048   50       delta-Cadinene
# 4    3133            5        0.034    5             Camphene
#
#             name_sort         cas  weight formula  \
# 0         ALPHAPINENE     80-56-8     NaN     NaN
# 1         DELTACARENE  13466-78-9     NaN     NaN
# 2  CARYOPHYLLENEOXIDE   1139-30-6     NaN     NaN
# 3       DELTACADINENE    483-76-1     NaN     NaN
# 4            CAMPHENE     79-92-5     NaN     NaN
#
#                                            smiles                 basic_smiles
# 0                               CC1=CCC2CC1C2(C)C            CC1=CCC2CC1C2(C)C
# 1                             CC1=CCC2C(C1)C2(C)C          CC1=CCC2C(C1)C2(C)C
# ...

# %%
Chem.MolFromSmiles("C=C1CCC2OC2(C)CCC2C1CC2(C)C")

# %%
Chem.MolFromSmiles("C[C@@]12CC[C@@H]3[C@H](CC3(C)C)C(=C)CC[C@H]1O2")

# %%
("C=C1CCC2OC2(C)CCC2C1CC2(C)C", ["CH3" => 3, "CY-CH2" => 5, "CY-CH" => 3, "CY-C" => 2,"CH2=C" => 1, "O"=>1])
# Out:
#   Cell In[5], line 1
#     ("C=C1CCC2OC2(C)CCC2C1CC2(C)C", ["CH3" => 3, "CY-CH2" => 5, "CY-CH" => 3, "CY-C" => 2,"CH2=C" => 1, "O"=>1])
#                                            ^
# SyntaxError: invalid syntax

# %%
Chem.MolFromSmiles("CC12CCC(CC1)C(C)(C)O2")#df.loc[20]["smiles"])

# %%
Chem.MolFromSmiles(df.loc[20]["smiles"])

# %%
("CC1(C2CCC(O1)(CC2)C)C", ["CH3" => 3, "CY-CH2" => 4, "CY-CH" => 1, "CY-C" => 2, "O"=>1])

# %%
Chem.MolFromSmiles("C=C1CCC2C(=C)CCC(C(C)C)C2C1")

# %% [markdown]
# ("C=C1CCC2C(=C)CCC(C(C)C)C2C1", ["CH3" => 2, "CH" => 1, "CY-CH2" => 5, "CY-CH" => 3, "CH2=C" => 2])

# %%
Chem.MolFromSmiles("CC1=CCC(C(C)C)C2CC(C)CCC12")

# %% [markdown]
# ("CC1=CCC(C(C)C)C2CC(C)CCC12", ["CH3" => 4, "CH" => 1, "CY-CH2" => 4, "CY-CH" => 4, "CH=C" => 1])

# %%
Chem.MolFromSmiles("CC1=CC2C(C(C)C)CCC(C)(O)C2CC1")

# %% [markdown]
# ("CC1=CC2C(C(C)C)CCC(C)(O)C2CC1", ["CH3" => 4, "CH" => 1, "CY-CH2" => 4, "CY-CH" => 3, "CY-C" => 1, "OH(T)" => 1, "CH=C" => 1])

# %%
Chem.MolFromSmiles("CC1(C)C2CCC1(C)C(O)C2")

# %% [markdown]
# ("CC1(C)C2CCC1(C)C(O)C2", ["CH3" => 3, "CY-CH2" => 3, "CY-CH" => 2, "CY-C" => 2, "OH(S)" => 1])

# %%
Chem.MolFromSmiles("CC1(C2CCC(O1)(CC2)C)C")

# %%
Chem.MolFromSmiles("CC12CCC(CC1)C(C)(C)O2")

# %%
Chem.MolFromSmiles("CC1(C2CCC(O1)(CC2)C)C")

# %% [markdown]
# ("CC1(C2CCC(O1)(CC2)C)C", ["CH3" => 3, "CY-CH2" => 4, "CY-CH" => 1, "CY-C" => 1, "TRIOXAN" => 1])

# %%
Chem.MolFromSmiles("CC12CCC(CC1)CO2")

# %%
Chem.MolFromSmiles("CC1(C2CCC(O1)(CC2)C)C")
