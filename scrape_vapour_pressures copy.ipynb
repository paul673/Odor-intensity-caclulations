# %%
import requests
from bs4 import BeautifulSoup

from selenium import webdriver
from selenium.webdriver.common.by import By

import time

import pandas as pd

# %%
def query_pubchem_cid(cas):
    """
    
    """
    #url = f"https://pubchem.ncbi.nlm.nih.gov/rest/pug/substance/name/{cas}/property/VaporPressure/JSON"
    url =f"https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/{cas}/property/Title,CanonicalSMILES/JSON"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()["PropertyTable"]["Properties"][0]
        print(f"Fetching {cas} ({data['Title']})")
        return data["CID"]
    else:
        return None

# %%
query_pubchem_cid("99-87-6")
# Out:
# Fetching 99-87-6 (p-CYMENE)
# 7463

# %%
def query_pubchem_by_cas(cas_number, driver):
    # Set up WebDriver (replace 'path_to_chromedriver' with your ChromeDriver path)
    #service = Service("C:/Users/paulj/Downloads/chromedriver_win32/chromedriver.exe")

    #driver = webdriver.Chrome(service=service)
    cid = query_pubchem_cid(cas_number)
    url = f"https://pubchem.ncbi.nlm.nih.gov/compound/{cid}#section=Vapor-Pressure&fullscreen=true"
    try:
        driver.get(url)
        time.sleep(3)  # Allow time for the page to load

        # Locate and parse the Antoine coefficients table
        section = driver.find_elements(By.TAG_NAME, "section")
        if len(section)>1:
            print("long list detected")
        section= section[0]
        if section.get_attribute("id") != "Vapor-Pressure":
            print("Not Vapor-Pressure detected")
        soup = BeautifulSoup(section.get_attribute("outerHTML"), "html.parser")
        data=soup.find_all("div", class_="break-words space-y-1")
        #values = section.find_elements(By.CLASS_NAME, "break-words space-y-1")
        #print(values)
        #result = [value.get_attribute("outerHTML") for value in values]

        result=data
        result = [v.getText() for v in data]
        return result
    except Exception as e:
        print(f"Error retrieving data for CAS {cas_number}: {e}")
        return None

# %%
def read_cas_data(csv_filepath="src/smiles_pine.csv"):
    df = pd.read_csv(csv_filepath)
    df = df[["cas", "name"]]
    return df

# %%
def main():
    df = read_cas_data()
    options = webdriver.ChromeOptions()
    options.page_load_strategy = 'normal'
    driver = webdriver.Chrome(options=options)

    results = []

    for i in df.index:
        row = list(df.loc[i])
        cas_num = row[0]
        name = row[1]
        print(f"Fetching {cas_num} ({name})")
        results.append(query_pubchem_by_cas(cas_num, driver))

    driver.quit()

    return results

# %%
scraped = main()
# Out:
# Fetching 80-56-8 (alpha-Pinene)
# Fetching 80-56-8 (alpha-PINENE)
# Fetching 13466-78-9 (delta-3-Carene)
# Fetching 13466-78-9 (3-Carene)
# Fetching 1139-30-6 (Caryophyllene oxide)
# Fetching 1139-30-6 (beta-CARYOPHYLLENE OXIDE)
# Error retrieving data for CAS 1139-30-6: list index out of range
# Fetching 483-76-1 (delta-Cadinene)
# Fetching 483-76-1 ((+)-delta-Cadinene)
# Error retrieving data for CAS 483-76-1: list index out of range
# Fetching 79-92-5 (Camphene)
# Fetching 79-92-5 (Camphene)
# Fetching 87-44-5 (beta-Caryophyllene)
# Fetching 87-44-5 (Caryophyllene)
# Error retrieving data for CAS 87-44-5: list index out of range
# Fetching 31983-22-9 (alpha-Muurolene)
# Fetching 31983-22-9 (alpha-Muurolene)
# Error retrieving data for CAS 31983-22-9: list index out of range
# Fetching 481-34-5 (alpha-Cadinol)
# Fetching 481-34-5 (Cadin-4-en-10-ol)
# Error retrieving data for CAS 481-34-5: list index out of range
# Fetching 586-62-9 (Terpinolene)
# Fetching 586-62-9 (Terpinolene)
# Fetching 127-91-3 (beta-Pinene)
# Fetching 127-91-3 (beta-Pinene)
# Fetching 123-35-3 (Myrcene)
# Fetching 123-35-3 (Myrcene)
# Fetching 30021-74-0 (gamma-Muurolene)
# Fetching 30021-74-0 ((1R,4aR,8aS)-7-methyl-4-methylidene-1-propan-2-yl-2,3,4a,5,6,8a-hexahydro-1H-naphthalene)
# Error retrieving data for CAS 30021-74-0: list index out of range
# Fetching 76-49-3 (Bornyl acetate)
# Fetching 76-49-3 (Bornyl acetate, (-)-)
# Fetching 3779-61-1 ((E)-beta-Ocimene)
# Fetching 3779-61-1 (beta-OCIMENE, (3E)-)
# Error retrieving data for CAS 3779-61-1: list index out of range
# Fetching 39029-41-9 (gamma-Cadinene)
# Fetching 39029-41-9 ((-)-gamma-Cadinene)
# Error retrieving data for CAS 39029-41-9: list index out of range
# Fetching 3387-41-5 (Sabinene)
# Fetching 3387-41-5 (Sabinen)
# Error retrieving data for CAS 3387-41-5: list index out of range
# Fetching 19912-62-0 (T-Muurolol)
# Fetching 19912-62-0 (T-Muurolol)
# Error retrieving data for CAS 19912-62-0: list index out of range
# Fetching 138-86-3 (Limonene)
# Fetching 138-86-3 (Limonene, (+/-)-)
# Fetching 502-61-4 (alpha-Farnesene)
# Fetching 502-61-4 (Alpha-Farnesene)
# Error retrieving data for CAS 502-61-4: list index out of range
# Fetching 508-32-7 (Tricyclene)
# Fetching 508-32-7 (Tricyclene)
# Error retrieving data for CAS 508-32-7: list index out of range
# Fetching 470-82-6 (1,8-Cineole)
# Fetching 470-82-6 (Eucalyptol)
# Fetching 555-10-2 (beta-Phellandrene)
# Fetching 555-10-2 (Beta-Phellandrene)
# Fetching 80-26-2 (alpha-Terpinyl acetate)
# Fetching 80-26-2 (alpha-Terpinyl acetate)
# Error retrieving data for CAS 80-26-2: list index out of range
# Fetching 6753-98-6 (alpha-Humulene)
# Fetching 6753-98-6 (Humulene)
# Error retrieving data for CAS 6753-98-6: list index out of range
# Fetching 5937-11-1 (T-Cadinol)
# Fetching 5937-11-1 (Cedrelanol)
# Error retrieving data for CAS 5937-11-1: list index out of range
# Fetching 562-74-3 (Terpinen-4-ol)
# Fetching 562-74-3 (4-Terpineol, (+/-)-)
# Error retrieving data for CAS 562-74-3: list index out of range
# Fetching 507-70-0 (Borneol)
# Fetching 507-70-0 (1,7,7-Trimethylbicyclo[2.2.1]heptan-2-ol)
# Fetching 515-13-9 (beta-Elemene)
# Fetching 515-13-9 (Beta-Elemene)
# Error retrieving data for CAS 515-13-9: list index out of range
# Fetching 99-85-4 (gamma-Terpinene)
# Fetching 99-85-4 (gamma-Terpinene)
# Fetching 3917-48-4 (alpha-Thujene)
# Fetching 3917-48-4 ((-)-alpha-Thujene)
# Error retrieving data for CAS 3917-48-4: list index out of range
# Fetching 483-77-2 (Calamenene)
# Fetching 483-77-2 (Calamenene)
# Error retrieving data for CAS 483-77-2: list index out of range
# Fetching 19435-97-3 (alpha-Muurolol)
# Fetching 19435-97-3 (delta-Cadinol)
# Error retrieving data for CAS 19435-97-3: list index out of range
# Fetching 77129-48-7 (beta-Farnesene)
# Fetching 77129-48-7 (beta-Farnesene)
# Error retrieving data for CAS 77129-48-7: list index out of range
# Fetching 15423-57-1 (Germacrene B)
# Fetching 15423-57-1 (Germacrene B)
# Error retrieving data for CAS 15423-57-1: list index out of range
# Fetching 99-86-5 (alpha-Terpinene)
# Fetching 99-86-5 (alpha-Terpinene)
# Error retrieving data for CAS 99-86-5: list index out of range
# Fetching 99-83-2 (alpha-Phellandrene)
# Fetching 99-83-2 (alpha-PHELLANDRENE)
# Fetching 25548-04-3 (epsilon-Muurolene)
# Fetching 25548-04-3 (Epsilon-Cadinene)
# Error retrieving data for CAS 25548-04-3: list index out of range
# Fetching 88-84-6 (beta-Guaiene)
# Fetching 88-84-6 (beta-Guaiene)
# Error retrieving data for CAS 88-84-6: list index out of range
# Fetching 5208-59-3 (beta-Bourbonene)
# Fetching 5208-59-3 (beta-Bourbonene)
# Error retrieving data for CAS 5208-59-3: list index out of range
# Fetching 20307-84-0 (delta-Elemene)
# Fetching 20307-84-0 (Cyclohexene, 4-ethenyl-4-methyl-3-(1-methylethenyl)-1-(1-methylethyl)-, (3R-trans)-)
# Error retrieving data for CAS 20307-84-0: list index out of range
# Fetching 98-55-5 (alpha-Terpineol)
# Fetching 98-55-5 (Alpha-Terpineol)
# Fetching 99-87-6 (para-Cymene)
# Fetching 99-87-6 (p-CYMENE)
# Fetching 3691-12-1 (alpha-Guaiene)
# Fetching 3691-12-1 (alpha-Guaiene)
# Error retrieving data for CAS 3691-12-1: list index out of range
# Fetching 475-20-7 (Longifolene)
# Fetching 475-20-7 ((+)-Longifolene)
# Error retrieving data for CAS 475-20-7: list index out of range
# Fetching 3856-25-5 (alpha-Copaene)
# Fetching 3856-25-5 (Copaene)
# Error retrieving data for CAS 3856-25-5: list index out of range
# Fetching 29350-73-0 (Cadinene (unknown isomer))
# Fetching 29350-73-0 (Naphthalene, decahydro-1,6-dimethyl-4-(1-methylethyl)-, (1S,4S,4aS,6S,8aS)-, didehydro deriv.)
# Fetching 18252-44-3 (beta-Copaene)
# Fetching 18252-44-3 (cis-beta-Copaene)
# Error retrieving data for CAS 18252-44-3: list index out of range
# Fetching 106-22-9 (Citronellol)
# Fetching 106-22-9 (beta-CITRONELLOL, (+/-)-)
# Fetching 106-24-1 (Geraniol)
# Fetching 106-24-1 (Geraniol)
# Fetching 17699-14-8 (alpha-Cubebene)
# Fetching 17699-14-8 (alpha-Cubebene)
# Error retrieving data for CAS 17699-14-8: list index out of range
# Fetching 76-22-2 (Camphor)
# Fetching 76-22-2 (Camphor)
# Fetching 947-59-1 (alpha-Ylangene)
# Fetching 947-59-1 (Copaene, (+)-)
# Error retrieving data for CAS 947-59-1: list index out of range
# Fetching 141-12-8 (Neryl acetate)
# Fetching 141-12-8 (Neryl acetate)
# Error retrieving data for CAS 141-12-8: list index out of range
# Fetching 105-87-3 (Geranyl acetate)
# Fetching 105-87-3 (Geranyl acetate)
# [['10 mmHg at 99.1 °F (NTP, 1992) ',
#   '4.75 [mmHg] ',
#   '4.75 mm Hg at 25 °C ',
#   '10 mmHg at 99.1 °F '],
#  ['3.72 [mmHg] '],
#  None,
#  None,
#  ['2.5 [mmHg] ', '2.5 mm Hg at 25 °C ', 'Vapor pressure, kPa at 20 °C: 0.4 '],
#  None,
#  None,
#  None,
#  ['0.74 [mmHg] ', '0.74 mm Hg at 25 °C '],
#  ['2.93 [mmHg] ', '2.93 mm Hg at 25 °C ', '2.93 mmHg '],
#  ['4.61 mmHg (USCG, 1999) ', '2.01 [mmHg] ', '2.09 mm Hg at 25 °C '],
#  None,
#  ['0.6 [mmHg] '],
#  None,
#  None,
#  None,
#  None,
#  ['1.55 [mmHg] ', '1.55 mm Hg at 25 °C /extrapolated/ '],
#  None,
#  None,
#  ['1.9 [mmHg] ', '1.90 mm Hg at 25 °C '],
#  ['1.59 [mmHg] '],
#  None,
#  None,
#  None,
#  None,
#  ['0.03 [mmHg] ', '5.02X10-2 mm Hg at 25 °C '],
#  None,
#  ['1.09 [mmHg] '],
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['1.4 [mmHg] '],
#  None,
#  None,
#  None,
#  None,
#  ['0.04 [mmHg] ',
#   '0.03 [mmHg] ',
#   'VP: 5 mm Hg at 80 to 81 mm Hg /L-alpha-Terpineol/',
#   '0.0423 mm Hg at 24 °C '],
#  ['1.46 [mmHg] ', '1.50 mm Hg at 25 °C ', 'Vapor pressure, Pa at 20 °C: 200 '],
#  None,
#  None,
#  None,
#  ['40 mmHg at 355.6 °F ; 1 mmHg at 214.3 °F; 760 mmHg at 527 °F (NTP, 1992) '],
#  None,
#  ['0.04 [mmHg] ', '0.02 mm Hg at 25 °C '],
#  ['0.03 [mmHg] '],
#  None,
#  ['0.2 mmHg (NIOSH, 2024) ',
#   '0.65 [mmHg] ',
#   'Vapor pressure = 27 Pa at 20 °C (= 0.20 mm Hg) ',
#   '0.65 mm Hg at 25 °C ',
#   'Vapor pressure, Pa at 20 °C: 27 ',
#   '0.2 mmHg '],
#  None,
#  None,
#  ['0.02 mmHg at 68 °F ; 1 mmHg at 164.3 °F (NTP, 1992) ', '0.03 [mmHg] ']]

# %%
"""cas_numbers =['99-87-6']

for cas in cas_numbers:
    data = query_pubchem_by_cas(cas)
    if data:
        print(f"Data for CAS {cas}: {data}")
    else:
        print(f"No data found for CAS {cas}")"""
# Out:
# 'cas_numbers =[\'99-87-6\']\n\nfor cas in cas_numbers:\n    data = query_pubchem_by_cas(cas)\n    if data:\n        print(f"Data for CAS {cas}: {data}")\n    else:\n        print(f"No data found for CAS {cas}")'

# %%
results = [['10 mmHg at 99.1 °F (NTP, 1992) ',
  '4.75 [mmHg] ',
  '4.75 mm Hg at 25 °C ',
  '10 mmHg at 99.1 °F '],
 ['3.72 [mmHg] '],
 None,
 None,
 ['2.5 [mmHg] ', '2.5 mm Hg at 25 °C ', 'Vapor pressure, kPa at 20 °C: 0.4 '],
 None,
 None,
 None,
 ['0.74 [mmHg] ', '0.74 mm Hg at 25 °C '],
 ['2.93 [mmHg] ', '2.93 mm Hg at 25 °C ', '2.93 mmHg '],
 ['4.61 mmHg (USCG, 1999) ', '2.01 [mmHg] ', '2.09 mm Hg at 25 °C '],
 None,
 ['0.6 [mmHg] '],
 None,
 None,
 None,
 None,
 ['1.55 [mmHg] ', '1.55 mm Hg at 25 °C /extrapolated/ '],
 None,
 None,
 ['1.9 [mmHg] ', '1.90 mm Hg at 25 °C '],
 ['1.59 [mmHg] '],
 None,
 None,
 None,
 None,
 ['0.03 [mmHg] ', '5.02X10-2 mm Hg at 25 °C '],
 None,
 ['1.09 [mmHg] '],
 None,
 None,
 None,
 None,
 None,
 None,
 ['1.4 [mmHg] '],
 None,
 None,
 None,
 None,
 ['0.04 [mmHg] ',
  '0.03 [mmHg] ',
  'VP: 5 mm Hg at 80 to 81 mm Hg /L-alpha-Terpineol/',
  '0.0423 mm Hg at 24 °C '],
 ['1.46 [mmHg] ', '1.50 mm Hg at 25 °C ', 'Vapor pressure, Pa at 20 °C: 200 '],
 None,
 None,
 None,
 ['40 mmHg at 355.6 °F ; 1 mmHg at 214.3 °F; 760 mmHg at 527 °F (NTP, 1992) '],
 None,
 ['0.04 [mmHg] ', '0.02 mm Hg at 25 °C '],
 ['0.03 [mmHg] '],
 None,
 ['0.2 mmHg (NIOSH, 2024) ',
  '0.65 [mmHg] ',
  'Vapor pressure = 27 Pa at 20 °C (= 0.20 mm Hg) ',
  '0.65 mm Hg at 25 °C ',
  'Vapor pressure, Pa at 20 °C: 27 ',
  '0.2 mmHg '],
 None,
 None,
 ['0.02 mmHg at 68 °F ; 1 mmHg at 164.3 °F (NTP, 1992) ', '0.03 [mmHg] ']]

# %%
lsts = [[None for i in results] for i in range(6)]
print(lsts)
for i, result in enumerate(results):
    if result!=None:
        for j, element in enumerate(result):
            lsts[j][i] = result[j]

    else:
        for j in range(6):
            lsts[j][i] = None

lsts
# Out:
# [[None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]]
# [['10 mmHg at 99.1 °F (NTP, 1992) ',
#   '3.72 [mmHg] ',
#   None,
#   None,
#   '2.5 [mmHg] ',
#   None,
#   None,
#   None,
#   '0.74 [mmHg] ',
#   '2.93 [mmHg] ',
#   '4.61 mmHg (USCG, 1999) ',
#   None,
#   '0.6 [mmHg] ',
#   None,
#   None,
#   None,
#   None,
#   '1.55 [mmHg] ',
#   None,
#   None,
#   '1.9 [mmHg] ',
#   '1.59 [mmHg] ',
#   None,
#   None,
#   None,
#   None,
#   '0.03 [mmHg] ',
#   None,
#   '1.09 [mmHg] ',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '1.4 [mmHg] ',
#   None,
#   None,
#   None,
#   None,
#   '0.04 [mmHg] ',
#   '1.46 [mmHg] ',
#   None,
#   None,
#   None,
#   '40 mmHg at 355.6 °F ; 1 mmHg at 214.3 °F; 760 mmHg at 527 °F (NTP, 1992) ',
#   None,
#   '0.04 [mmHg] ',
#   '0.03 [mmHg] ',
#   None,
#   '0.2 mmHg (NIOSH, 2024) ',
#   None,
#   None,
#   '0.02 mmHg at 68 °F ; 1 mmHg at 164.3 °F (NTP, 1992) '],
#  ['4.75 [mmHg] ',
#   None,
#   None,
#   None,
#   '2.5 mm Hg at 25 °C ',
#   None,
#   None,
#   None,
#   '0.74 mm Hg at 25 °C ',
#   '2.93 mm Hg at 25 °C ',
#   '2.01 [mmHg] ',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '1.55 mm Hg at 25 °C /extrapolated/ ',
#   None,
#   None,
#   '1.90 mm Hg at 25 °C ',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '5.02X10-2 mm Hg at 25 °C ',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '0.03 [mmHg] ',
#   '1.50 mm Hg at 25 °C ',
#   None,
#   None,
#   None,
#   None,
#   None,
#   '0.02 mm Hg at 25 °C ',
#   None,
#   None,
#   '0.65 [mmHg] ',
#   None,
#   None,
#   '0.03 [mmHg] '],
#  ['4.75 mm Hg at 25 °C ',
#   None,
#   None,
#   None,
#   'Vapor pressure, kPa at 20 °C: 0.4 ',
#   None,
#   None,
#   None,
#   None,
#   '2.93 mmHg ',
#   '2.09 mm Hg at 25 °C ',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'VP: 5 mm Hg at 80 to 81 mm Hg /L-alpha-Terpineol/',
#   'Vapor pressure, Pa at 20 °C: 200 ',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'Vapor pressure = 27 Pa at 20 °C (= 0.20 mm Hg) ',
#   None,
#   None,
#   None],
#  ['10 mmHg at 99.1 °F ',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '0.0423 mm Hg at 24 °C ',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '0.65 mm Hg at 25 °C ',
#   None,
#   None,
#   None],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'Vapor pressure, Pa at 20 °C: 27 ',
#   None,
#   None,
#   None],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   '0.2 mmHg ',
#   None,
#   None,
#   None]]

# %%
new_df=pd.DataFrame(
    {
        i: lsts[i] for i in range(6)
    }
)
new_df
# Out:
#                                                     0  \
# 0                     10 mmHg at 99.1 °F (NTP, 1992)
# 1                                        3.72 [mmHg]
# 2                                                None
# 3                                                None
# 4                                         2.5 [mmHg]
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                        0.74 [mmHg]
# 9                                        2.93 [mmHg]
# 10                            4.61 mmHg (USCG, 1999)
# 11                                               None
# 12                                        0.6 [mmHg]
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                       1.55 [mmHg]
# 18                                               None
# 19                                               None
# 20                                        1.9 [mmHg]
# 21                                       1.59 [mmHg]
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                       0.03 [mmHg]
# 27                                               None
# 28                                       1.09 [mmHg]
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                        1.4 [mmHg]
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                       0.04 [mmHg]
# 41                                       1.46 [mmHg]
# 42                                               None
# 43                                               None
# 44                                               None
# 45  40 mmHg at 355.6 °F ; 1 mmHg at 214.3 °F; 760 ...
# 46                                               None
# 47                                       0.04 [mmHg]
# 48                                       0.03 [mmHg]
# 49                                               None
# 50                            0.2 mmHg (NIOSH, 2024)
# 51                                               None
# 52                                               None
# 53  0.02 mmHg at 68 °F ; 1 mmHg at 164.3 °F (NTP, ...
#
#                                       1  \
# 0                          4.75 [mmHg]
# 1                                  None
# 2                                  None
# 3                                  None
# 4                   2.5 mm Hg at 25 °C
# 5                                  None
# 6                                  None
# 7                                  None
# 8                  0.74 mm Hg at 25 °C
# 9                  2.93 mm Hg at 25 °C
# 10                         2.01 [mmHg]
# 11                                 None
# 12                                 None
# 13                                 None
# 14                                 None
# 15                                 None
# 16                                 None
# 17  1.55 mm Hg at 25 °C /extrapolated/
# 18                                 None
# 19                                 None
# 20                 1.90 mm Hg at 25 °C
# 21                                 None
# 22                                 None
# 23                                 None
# 24                                 None
# 25                                 None
# 26            5.02X10-2 mm Hg at 25 °C
# 27                                 None
# 28                                 None
# 29                                 None
# 30                                 None
# 31                                 None
# 32                                 None
# 33                                 None
# 34                                 None
# 35                                 None
# 36                                 None
# 37                                 None
# 38                                 None
# 39                                 None
# 40                         0.03 [mmHg]
# 41                 1.50 mm Hg at 25 °C
# 42                                 None
# 43                                 None
# 44                                 None
# 45                                 None
# 46                                 None
# 47                 0.02 mm Hg at 25 °C
# 48                                 None
# 49                                 None
# 50                         0.65 [mmHg]
# 51                                 None
# 52                                 None
# 53                         0.03 [mmHg]
#
#                                                     2                       3  \
# 0                                4.75 mm Hg at 25 °C      10 mmHg at 99.1 °F
# 1                                                None                    None
# 2                                                None                    None
# 3                                                None                    None
# 4                  Vapor pressure, kPa at 20 °C: 0.4                     None
# 5                                                None                    None
# 6                                                None                    None
# 7                                                None                    None
# 8                                                None                    None
# 9                                          2.93 mmHg                     None
# 10                               2.09 mm Hg at 25 °C                     None
# 11                                               None                    None
# 12                                               None                    None
# 13                                               None                    None
# 14                                               None                    None
# 15                                               None                    None
# 16                                               None                    None
# 17                                               None                    None
# 18                                               None                    None
# 19                                               None                    None
# 20                                               None                    None
# 21                                               None                    None
# 22                                               None                    None
# 23                                               None                    None
# 24                                               None                    None
# 25                                               None                    None
# 26                                               None                    None
# 27                                               None                    None
# 28                                               None                    None
# 29                                               None                    None
# 30                                               None                    None
# 31                                               None                    None
# 32                                               None                    None
# 33                                               None                    None
# 34                                               None                    None
# 35                                               None                    None
# 36                                               None                    None
# 37                                               None                    None
# 38                                               None                    None
# 39                                               None                    None
# 40  VP: 5 mm Hg at 80 to 81 mm Hg /L-alpha-Terpineol/  0.0423 mm Hg at 24 °C
# 41                  Vapor pressure, Pa at 20 °C: 200                     None
# 42                                               None                    None
# 43                                               None                    None
# 44                                               None                    None
# 45                                               None                    None
# 46                                               None                    None
# 47                                               None                    None
# 48                                               None                    None
# 49                                               None                    None
# 50    Vapor pressure = 27 Pa at 20 °C (= 0.20 mm Hg)     0.65 mm Hg at 25 °C
# 51                                               None                    None
# 52                                               None                    None
# 53                                               None                    None
#
#                                    4          5
# 0                               None       None
# 1                               None       None
# 2                               None       None
# 3                               None       None
# 4                               None       None
# 5                               None       None
# 6                               None       None
# 7                               None       None
# 8                               None       None
# 9                               None       None
# 10                              None       None
# 11                              None       None
# 12                              None       None
# 13                              None       None
# 14                              None       None
# 15                              None       None
# 16                              None       None
# 17                              None       None
# 18                              None       None
# 19                              None       None
# 20                              None       None
# 21                              None       None
# 22                              None       None
# 23                              None       None
# 24                              None       None
# 25                              None       None
# 26                              None       None
# 27                              None       None
# 28                              None       None
# 29                              None       None
# 30                              None       None
# 31                              None       None
# 32                              None       None
# 33                              None       None
# 34                              None       None
# 35                              None       None
# 36                              None       None
# 37                              None       None
# 38                              None       None
# 39                              None       None
# 40                              None       None
# 41                              None       None
# 42                              None       None
# 43                              None       None
# 44                              None       None
# 45                              None       None
# 46                              None       None
# 47                              None       None
# 48                              None       None
# 49                              None       None
# 50  Vapor pressure, Pa at 20 °C: 27   0.2 mmHg
# 51                              None       None
# 52                              None       None
# 53                              None       None
